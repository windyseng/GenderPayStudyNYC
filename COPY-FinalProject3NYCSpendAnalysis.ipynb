# %%
#Import tools
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
#Read data and import full file.
df = pd.read_csv('/Users/windyseng/Desktop/Project/FY17NYCSpendDataQ1-Q4.csv', header=None, low_memory=False)
df.columns = ['Quarter','Invoice Paid Date','Fiscal Year','Supplier ID','Supplier Name.Level1','Supplier Name.Level2','Commodity L1','Commodity L2','Commodity L3','PR Department','Unit of Appropriation','MA Contract Number','PR Doc ID','FMS Commodity Code','FMS Commodity Level 1','FMS Commodity Level 2','Industry','Award Doc Code Name','Budget Code Label','Fund Name','Award Number','Award Doc Identification Name','Award Doc Identification Description v','Award Details Award Method Code','Award Details Award Method Name','Award Details Contract Class Code','Award Details Contract Class Name','Award Hdr Electronic Order Type Detail','Award Hdr Original Max Contract Amount','Award Hdr Max Contract Amt','Award Doc Version No','Award Comm Line Description','Award Doc Dept Code','Award Doc Dept Name','MWBE Status','Amount in USD']
df.head()
# Out:
#    Quarter Invoice Paid Date  Fiscal Year Supplier ID   Supplier Name.Level1  \
# 0        1            7/1/16         2017  VS00010491            ITEGIX LLC-
# 1        1            7/1/16         2017  VS00010491            ITEGIX LLC-
# 2        1            7/1/16         2017  VS00010491            ITEGIX LLC-
# 3        1            7/1/16         2017      523574  GENERAL FOUNDRIES INC
# 4        1            7/1/16         2017      624822   NU-TECH PRODUCTS INC
#
#     Supplier Name.Level2              Commodity L1        Commodity L2  \
# 0             ITEGIX LLC  General & Administrative      Fleet Vehicles
# 1             ITEGIX LLC  General & Administrative      Fleet Vehicles
# 2             ITEGIX LLC  General & Administrative      Fleet Vehicles
# 3  GENERAL FOUNDRIES INC                Facilities  Building Materials
# 4   NU-TECH PRODUCTS INC                Facilities        MRO Supplies
#
#                           Commodity L3                      PR Department  \
# 0   Fleet Vehicle Maintenance & Repair              056-POLICE DEPARTMENT
# 1   Fleet Vehicle Maintenance & Repair              056-POLICE DEPARTMENT
# 2   Fleet Vehicle Maintenance & Repair              056-POLICE DEPARTMENT
# 3  Construction Supplies and Materials   841-DEPARTMENT OF TRANSPORTATION
# 4                  Janitorial Supplies  069-DEPARTMENT OF SOCIAL SERVICES
#
#        ...      Award Details Contract Class Name  \
# 0      ...               EXPENSE/GENERAL CONTRACT
# 1      ...               EXPENSE/GENERAL CONTRACT
# 2      ...               EXPENSE/GENERAL CONTRACT
# 3      ...               EXPENSE/GENERAL CONTRACT
# 4      ...               EXPENSE/GENERAL CONTRACT
#
#   Award Hdr Electronic Order Type Detail  \
# 0                                (blank)
# 1                                (blank)
# 2                                (blank)
# 3                                (blank)
# 4                                (blank)
#
#   Award Hdr Original Max Contract Amount Award Hdr Max Contract Amt  \
# 0                                 17,397                     17,397
# 1                                 17,397                     17,397
# 2                                 17,397                     17,397
# 3                                 31,000                     31,000
# 4                                  1,978                      1,978
#
#   Award Doc Version No                        Award Comm Line Description  \
# 0                    1                                             GARMIN
# 1                    1                                             GARMIN
# 2                    1                                             GARMIN
# 3                    1                                        SEWER COVER
# 4                    1  FABRICATE AND PROVIDE PLASTIC BATHROOM PARTITIONS
#
#   Award Doc Dept Code            Award Doc Dept Name MWBE Status Amount in USD
# 0                  56              Police Department          No           396
# 1                  56              Police Department          No         2,835
# 2                  56              Police Department          No         3,690
# 3                 841   Department of Transportation          No         6,200
# 4                  69  Department of Social Services          No         1,978
#
# [5 rows x 36 columns]

# %%
#Review the number of observations in the dataset
df.count()
# Out:
# Quarter                                   388523
# Invoice Paid Date                         388523
# Fiscal Year                               388523
# Supplier ID                               388523
# Supplier Name.Level1                      388523
# Supplier Name.Level2                      388523
# Commodity L1                              388523
# Commodity L2                              388523
# Commodity L3                              388523
# PR Department                             388523
# Unit of Appropriation                     388523
# MA Contract Number                        388523
# PR Doc ID                                 388523
# FMS Commodity Code                        388523
# FMS Commodity Level 1                     388523
# FMS Commodity Level 2                     388523
# Industry                                  388523
# Award Doc Code Name                       388523
# Budget Code Label                         388523
# Fund Name                                 388523
# Award Number                              388523
# Award Doc Identification Name             388523
# Award Doc Identification Description v    388523
# Award Details Award Method Code           388523
# Award Details Award Method Name           388523
# Award Details Contract Class Code         388523
# Award Details Contract Class Name         388523
# Award Hdr Electronic Order Type Detail    388523
# Award Hdr Original Max Contract Amount    388523
# Award Hdr Max Contract Amt                388523
# Award Doc Version No                      388523
# Award Comm Line Description               388523
# Award Doc Dept Code                       388523
# Award Doc Dept Name                       388523
# MWBE Status                               388523
# Amount in USD                             388523
# dtype: int64

# %%
#Summary table
df.describe()
# Out:
#              Quarter  Fiscal Year  Award Doc Dept Code
# count  388523.000000     388523.0        388523.000000
# mean        2.518628       2017.0           597.439593
# std         1.111302          0.0           351.293094
# min         1.000000       2017.0             2.000000
# 25%         2.000000       2017.0            71.000000
# 50%         3.000000       2017.0           826.000000
# 75%         4.000000       2017.0           857.000000
# max         4.000000       2017.0           902.000000

# %%
#Replace spaces and periods in the column names to make sure you can call the parameters later using replace.
df.columns = pd.Series(df.columns).str.replace(' ','_') #replaces all the spaces within the column titles
df.columns = pd.Series(df.columns).str.replace('.','_') #replaces all the periods within the column titles
df.columns = [x.strip().replace(' ', '_') for x in df.columns]#replaces all the spaces within the rows
df.head() #prints the first 5 rows in the dataframe
# Out:
#    Quarter Invoice_Paid_Date  Fiscal_Year Supplier_ID   Supplier_Name_Level1  \
# 0        1            7/1/16         2017  VS00010491            ITEGIX LLC-
# 1        1            7/1/16         2017  VS00010491            ITEGIX LLC-
# 2        1            7/1/16         2017  VS00010491            ITEGIX LLC-
# 3        1            7/1/16         2017      523574  GENERAL FOUNDRIES INC
# 4        1            7/1/16         2017      624822   NU-TECH PRODUCTS INC
#
#     Supplier_Name_Level2              Commodity_L1        Commodity_L2  \
# 0             ITEGIX LLC  General & Administrative      Fleet Vehicles
# 1             ITEGIX LLC  General & Administrative      Fleet Vehicles
# 2             ITEGIX LLC  General & Administrative      Fleet Vehicles
# 3  GENERAL FOUNDRIES INC                Facilities  Building Materials
# 4   NU-TECH PRODUCTS INC                Facilities        MRO Supplies
#
#                           Commodity_L3                      PR_Department  \
# 0   Fleet Vehicle Maintenance & Repair              056-POLICE DEPARTMENT
# 1   Fleet Vehicle Maintenance & Repair              056-POLICE DEPARTMENT
# 2   Fleet Vehicle Maintenance & Repair              056-POLICE DEPARTMENT
# 3  Construction Supplies and Materials   841-DEPARTMENT OF TRANSPORTATION
# 4                  Janitorial Supplies  069-DEPARTMENT OF SOCIAL SERVICES
#
#        ...      Award_Details_Contract_Class_Name  \
# 0      ...               EXPENSE/GENERAL CONTRACT
# 1      ...               EXPENSE/GENERAL CONTRACT
# 2      ...               EXPENSE/GENERAL CONTRACT
# 3      ...               EXPENSE/GENERAL CONTRACT
# 4      ...               EXPENSE/GENERAL CONTRACT
#
#   Award_Hdr_Electronic_Order_Type_Detail  \
# 0                                (blank)
# 1                                (blank)
# 2                                (blank)
# 3                                (blank)
# 4                                (blank)
#
#   Award_Hdr_Original_Max_Contract_Amount Award_Hdr_Max_Contract_Amt  \
# 0                                 17,397                     17,397
# 1                                 17,397                     17,397
# 2                                 17,397                     17,397
# 3                                 31,000                     31,000
# 4                                  1,978                      1,978
#
#   Award_Doc_Version_No                        Award_Comm_Line_Description  \
# 0                    1                                             GARMIN
# 1                    1                                             GARMIN
# 2                    1                                             GARMIN
# 3                    1                                        SEWER COVER
# 4                    1  FABRICATE AND PROVIDE PLASTIC BATHROOM PARTITIONS
#
#   Award_Doc_Dept_Code            Award_Doc_Dept_Name MWBE_Status Amount_in_USD
# 0                  56              Police Department          No           396
# 1                  56              Police Department          No         2,835
# 2                  56              Police Department          No         3,690
# 3                 841   Department of Transportation          No         6,200
# 4                  69  Department of Social Services          No         1,978
#
# [5 rows x 36 columns]

# %%
#Create a subset of the dataframe using first 100 rows and selecting specific columns to test.
subset=df[['Quarter','Supplier_Name_Level1','PR_Department','Commodity_L2','Amount_in_USD']]
test=subset.iloc[1:101, 0:5]
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 1 to 100
# Data columns (total 5 columns):
# Quarter                 100 non-null int64
# Supplier_Name_Level1    100 non-null object
# PR_Department           100 non-null object
# Commodity_L2            100 non-null object
# Amount_in_USD           100 non-null object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
#Drop NA values from subset if any
test.dropna(subset = ['Quarter','Supplier_Name_Level1','PR_Department','Commodity_L2','Amount_in_USD'])
# Out:
#      Quarter                               Supplier_Name_Level1  \
# 1          1                                        ITEGIX LLC-
# 2          1                                        ITEGIX LLC-
# 3          1                              GENERAL FOUNDRIES INC
# 4          1                               NU-TECH PRODUCTS INC
# 5          1                                  GLOBAL PACKAGING-
# 6          1                                    SID TOOL CO INC
# 7          1                                   EDGE ELECTRONICS
# 8          1                                   EDGE ELECTRONICS
# 9          1                                   EDGE ELECTRONICS
# 10         1                                   EDGE ELECTRONICS
# 11         1                                   EDGE ELECTRONICS
# 12         1                                   EDGE ELECTRONICS
# 13         1                                   EDGE ELECTRONICS
# 14         1                                   EDGE ELECTRONICS
# 15         1                                   EDGE ELECTRONICS
# 16         1                                   EDGE ELECTRONICS
# 17         1                                   EDGE ELECTRONICS
# 18         1                                   EDGE ELECTRONICS
# 19         1                                   EDGE ELECTRONICS
# 20         1                                   EDGE ELECTRONICS
# 21         1                                   EDGE ELECTRONICS
# 22         1                                   EDGE ELECTRONICS
# 23         1                                   EDGE ELECTRONICS
# 24         1                                   EDGE ELECTRONICS
# 25         1                                   EDGE ELECTRONICS
# 26         1                                   EDGE ELECTRONICS
# 27         1                                   EDGE ELECTRONICS
# 28         1                                   EDGE ELECTRONICS
# 29         1                                   EDGE ELECTRONICS
# 30         1                                   EDGE ELECTRONICS
# ..       ...                                                ...
# 71         1                                            BYR INC
# 72         1                                      ACCELERY, LLC
# 73         1                                    EASTERN HORIZON
# 74         1                                 TOOLS FOR INDUSTRY
# 75         1                                              FEDEX
# 76         1                           UNITED PARCEL SERVICE NY
# 77         1                           UNITED PARCEL SERVICE NY
# 78         1                             SCHOOL BUS BY SUPERIOR
# 79         1                             SCHOOL BUS BY SUPERIOR
# 80         1       LINCOLN CENTER FOR THE PERFORMING ARTS, INC.
# 81         1                                       LANCE WALKER
# 82         1                                         EZ COURIER
# 83         1                                         EZ COURIER
# 84         1                                         EZ COURIER
# 85         1                                         EZ COURIER
# 86         1                                         EZ COURIER
# 87         1                                         EZ COURIER
# 88         1                                         EZ COURIER
# 89         1                                         EZ COURIER
# 90         1                                              FEDEX
# 91         1                           UNITED PARCEL SERVICE NY
# 92         1                                    SID TOOL CO INC
# 93         1                                  GLOBAL PACKAGING-
# 94         1                                    EASTERN HORIZON
# 95         1                                            VERIZON
# 96         1                                            VERIZON
# 97         1                                            VERIZON
# 98         1            GOVERNMENT AGENCIES AND TAX AUTHORITIES
# 99         1  DEPT OF TREASURY FEDERAL LAW ENFORCEMENT TRAIN...
# 100        1                              LIBERTY GLASS CO INC-
#
#                                          PR_Department  \
# 1                                056-POLICE DEPARTMENT
# 2                                056-POLICE DEPARTMENT
# 3                     841-DEPARTMENT OF TRANSPORTATION
# 4                    069-DEPARTMENT OF SOCIAL SERVICES
# 5                     841-DEPARTMENT OF TRANSPORTATION
# 6                     841-DEPARTMENT OF TRANSPORTATION
# 7                                056-POLICE DEPARTMENT
# 8                                056-POLICE DEPARTMENT
# 9                                056-POLICE DEPARTMENT
# 10                               056-POLICE DEPARTMENT
# 11                               056-POLICE DEPARTMENT
# 12                               056-POLICE DEPARTMENT
# 13                               056-POLICE DEPARTMENT
# 14                               056-POLICE DEPARTMENT
# 15                               056-POLICE DEPARTMENT
# 16                               056-POLICE DEPARTMENT
# 17                               056-POLICE DEPARTMENT
# 18                               056-POLICE DEPARTMENT
# 19                               056-POLICE DEPARTMENT
# 20                               056-POLICE DEPARTMENT
# 21                               056-POLICE DEPARTMENT
# 22                               056-POLICE DEPARTMENT
# 23                               056-POLICE DEPARTMENT
# 24                               056-POLICE DEPARTMENT
# 25                               056-POLICE DEPARTMENT
# 26                               056-POLICE DEPARTMENT
# 27                               056-POLICE DEPARTMENT
# 28                               056-POLICE DEPARTMENT
# 29                               056-POLICE DEPARTMENT
# 30                               056-POLICE DEPARTMENT
# ..                                                 ...
# 71                               056-POLICE DEPARTMENT
# 72                               056-POLICE DEPARTMENT
# 73                               056-POLICE DEPARTMENT
# 74                               056-POLICE DEPARTMENT
# 75         816-DEPARTMENT OF HEALTH AND MENTAL HYGIENE
# 76         816-DEPARTMENT OF HEALTH AND MENTAL HYGIENE
# 77         816-DEPARTMENT OF HEALTH AND MENTAL HYGIENE
# 78   260-DEPARTMENT OF YOUTH AND COMMUNITY DEVELOPMENT
# 79   260-DEPARTMENT OF YOUTH AND COMMUNITY DEVELOPMENT
# 80   260-DEPARTMENT OF YOUTH AND COMMUNITY DEVELOPMENT
# 81         816-DEPARTMENT OF HEALTH AND MENTAL HYGIENE
# 82         816-DEPARTMENT OF HEALTH AND MENTAL HYGIENE
# 83         816-DEPARTMENT OF HEALTH AND MENTAL HYGIENE
# 84         816-DEPARTMENT OF HEALTH AND MENTAL HYGIENE
# 85         816-DEPARTMENT OF HEALTH AND MENTAL HYGIENE
# 86         816-DEPARTMENT OF HEALTH AND MENTAL HYGIENE
# 87         816-DEPARTMENT OF HEALTH AND MENTAL HYGIENE
# 88         816-DEPARTMENT OF HEALTH AND MENTAL HYGIENE
# 89         816-DEPARTMENT OF HEALTH AND MENTAL HYGIENE
# 90         816-DEPARTMENT OF HEALTH AND MENTAL HYGIENE
# 91         816-DEPARTMENT OF HEALTH AND MENTAL HYGIENE
# 92                    841-DEPARTMENT OF TRANSPORTATION
# 93                    841-DEPARTMENT OF TRANSPORTATION
# 94                               056-POLICE DEPARTMENT
# 95                               056-POLICE DEPARTMENT
# 96                               056-POLICE DEPARTMENT
# 97                               056-POLICE DEPARTMENT
# 98                               056-POLICE DEPARTMENT
# 99                               056-POLICE DEPARTMENT
# 100                              056-POLICE DEPARTMENT
#
#                   Commodity_L2 Amount_in_USD
# 1               Fleet Vehicles         2,835
# 2               Fleet Vehicles         3,690
# 3           Building Materials         6,200
# 4                 MRO Supplies         1,978
# 5                    Packaging            62
# 6                 MRO Supplies            49
# 7                 MRO Supplies           121
# 8                 MRO Supplies            95
# 9                 MRO Supplies            42
# 10                MRO Supplies         1,147
# 11                MRO Supplies           180
# 12                MRO Supplies            77
# 13                MRO Supplies            63
# 14                MRO Supplies            63
# 15                MRO Supplies           109
# 16                MRO Supplies           398
# 17                MRO Supplies           119
# 18                MRO Supplies           228
# 19                MRO Supplies           106
# 20                MRO Supplies           342
# 21                MRO Supplies            58
# 22                MRO Supplies            58
# 23                MRO Supplies            54
# 24                MRO Supplies           400
# 25                MRO Supplies         1,478
# 26                MRO Supplies            52
# 27                MRO Supplies           241
# 28                MRO Supplies           241
# 29                MRO Supplies           241
# 30                MRO Supplies           430
# ..                         ...           ...
# 71                   Equipment            45
# 72                       Other         1,000
# 73                   Equipment           100
# 74                       Other            40
# 75                    Shipping           779
# 76                    Shipping            92
# 77                    Shipping           249
# 78                      Travel           850
# 79                      Travel         1,805
# 80                      Grants        39,950
# 81                       Other           500
# 82                       Other            65
# 83                       Other           260
# 84                       Other            40
# 85                       Other            40
# 86                       Other           275
# 87                       Other            40
# 88                       Other           575
# 89                       Other           590
# 90                    Shipping           288
# 91                    Shipping           100
# 92                MRO Supplies            70
# 93                   Equipment           580
# 94                   Equipment         4,920
# 95              Communications         2,457
# 96              Communications         4,152
# 97              Communications         3,880
# 98   Taxes and Regulatory Fees           320
# 99        WorkForce Management         2,219
# 100             Fleet Vehicles           206
#
# [100 rows x 5 columns]

# %%
import seaborn as sb
# %matplotlib inline

sb.factorplot(
    x='Quarter',
    y='Amount_in_USD',
    data=test, 
    kind='box'
);

# %%
#Convert last column to numeric
test[['Amount_in_USD']] = test[['Amount_in_USD']].apply(pd.to_numeric, errors='coerce')

# %%
#remove spaces in between column names
test['Commodity_L2']=test['Commodity_L2'].replace(' ', '_')
test['PR_Department']=test['PR_Department'].replace(' ', '_')
test['Supplier_Name_Level1']=test['Supplier_Name_Level1'].replace(' ', '_')

# %%
#convert columns to strings
test[['Quarter']]=str(test[['Quarter']])
test[['Supplier_Name_Level1']]=str(test[['Supplier_Name_Level1']])
test[['PR_Department']]=str(test[['PR_Department']])
test[['Commodity_L2']]=str(test[['Commodity_L2']])

# %%
import seaborn as sb
# %matplotlib inline

sb.factorplot(
    x='Quarter',
    y='Amount_in_USD',
    data=test, 
    kind='box'
);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-f2168a794d20> in <module>()
#       6     y='Amount_in_USD',
#       7     data=test,
# ----> 8     kind='box'
#       9 );
#
# /Applications/anaconda/lib/python2.7/site-packages/seaborn/categorical.pyc in factorplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, size, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3428
#    3429     # Draw the plot onto the facets
# -> 3430     g.map_dataframe(plot_func, x, y, hue, **plot_kws)
#    3431
#    3432     # Special case axis labels for a count type plot
#
# /Applications/anaconda/lib/python2.7/site-packages/seaborn/axisgrid.pyc in map_dataframe(self, func, *args, **kwargs)
#     795
#     796         # Finalize the annotations and layout
# --> 797         self._finalize_grid(args[:2])
#     798
#     799         return self
#
# /Applications/anaconda/lib/python2.7/site-packages/seaborn/axisgrid.pyc in _finalize_grid(self, axlabels)
#     820         self.set_axis_labels(*axlabels)
#     821         self.set_titles()
# --> 822         self.fig.tight_layout()
#     823
#     824     def facet_axis(self, row_i, col_j):
#
# /Applications/anaconda/lib/python2.7/site-packages/matplotlib/figure.pyc in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    1753                                          rect=rect)
#    1754
# -> 1755         self.subplots_adjust(**kwargs)
#    1756
#    1757
#
# /Applications/anaconda/lib/python2.7/site-packages/matplotlib/figure.pyc in subplots_adjust(self, *args, **kwargs)
#    1618
#    1619         """
# -> 1620         self.subplotpars.update(*args, **kwargs)
#    1621         for ax in self.axes:
#    1622             if not isinstance(ax, SubplotBase):
#
# /Applications/anaconda/lib/python2.7/site-packages/matplotlib/figure.pyc in update(self, left, bottom, right, top, wspace, hspace)
#     230             if self.bottom >= self.top:
#     231                 reset()
# --> 232                 raise ValueError('bottom cannot be >= top')
#     233
#     234     def _update_this(self, s, val):
#
# ValueError: bottom cannot be >= top

# %%
import seaborn as sns
sns.kdeplot(test['Amount_in_USD'])

# %%
import seaborn as sns
corr = test.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
import pandas as pd
import matplotlib.pylab as plt
from sklearn import preprocessing
from scipy.stats import skew

# %%
#FillNa
test['Quarter'].fillna(0,inplace=True)
test['Supplier_Name_Level1'].fillna(0,inplace=True)
test['PR_Department'].fillna(0,inplace=True)
test['Commodity_L2'].fillna(0,inplace=True)
test['Amount_in_USD'].fillna(0,inplace=True)

# %%
spend=preprocessing.scale(test['Amount_in_USD'])
skness=skew(spend)

# %%
figure = plt.figure()
figure.add_subplot(121)   
plt.hist(spend,facecolor='blue',alpha=0.5) 
plt.xlabel("Spend") 
plt.title("Spend in USD Histogram") 
plt.text(2,100,"Skewness: {0:.2f}".format(skness)) 

figure.add_subplot(122) 
plt.boxplot(spend)
plt.title("Large Skewness shows Right Skewed Distribution")
plt.show()

# %%
import plotly
plotly.__version__
# Out:
# '2.0.15'

# %%
import plotly.plotly as py
import cufflinks as cf
import pandas as pd

cf.set_config_file(offline=False, world_readable=True, theme='pearl')

test.iplot(kind='bubble', x='PR_Department', y='Quarter', size='Amount_in_USD', text='PR_Department',
             xTitle='Agency', yTitle='Spend (in $)',
             filename='/Users/windyseng/Desktop/Project/FY17NYCSpendDataQ1-Q4.csv')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-68-ef0c47339fb3> in <module>()
#       7 test.iplot(kind='bubble', x='PR_Department', y='Quarter', size='Amount_in_USD', text='PR_Department',
#       8              xTitle='Agency', yTitle='Spend (in $)',
# ----> 9              filename='/Users/windyseng/Desktop/Project/FY17NYCSpendDataQ1-Q4.csv')
#
# /Applications/anaconda/lib/python2.7/site-packages/cufflinks/plotlytools.pyc in _iplot(self, data, layout, filename, sharing, kind, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#    1043                 return py.plot(figure,sharing=sharing,filename=filename,validate=validate,auto_open=False)
#    1044         else:
# -> 1045                 return iplot(figure,sharing=sharing,filename=filename,validate=validate,online=online)
#    1046
#    1047
#
# /Applications/anaconda/lib/python2.7/site-packages/cufflinks/plotlytools.pyc in iplot(data_or_figure, validate, sharing, filename, online, **kwargs)
#    1187                         filename='Plotly Playground {0}'.format(time.strftime("%Y-%m-%d %H:%M:%S"))
#    1188 		return py.iplot(data_or_figure,validate=validate,sharing=sharing,
# -> 1189 						filename=filename)
#    1190
#    1191 def _ta_figure(self,**kwargs):
#
# /Applications/anaconda/lib/python2.7/site-packages/plotly/plotly/plotly.pyc in iplot(figure_or_data, **plot_options)
#     133     if 'auto_open' not in plot_options:
#     134         plot_options['auto_open'] = False
# --> 135     url = plot(figure_or_data, **plot_options)
#     136
#     137     if isinstance(figure_or_data, dict):
#
# /Applications/anaconda/lib/python2.7/site-packages/plotly/plotly/plotly.pyc in plot(figure_or_data, validate, **plot_options)
#     226     data = fig.get('data', [])
#     227     plot_options['layout'] = fig.get('layout', {})
# --> 228     response = v1.clientresp(data, **plot_options)
#     229
#     230     # Check if the url needs a secret key
#
# /Applications/anaconda/lib/python2.7/site-packages/plotly/api/v1/clientresp.pyc in clientresp(data, **kwargs)
#      33
#      34     url = '{plotly_domain}/clientresp'.format(**cfg)
# ---> 35     response = request('post', url, data=payload)
#      36
#      37     # Old functionality, just keeping it around.
#
# /Applications/anaconda/lib/python2.7/site-packages/plotly/api/v1/utils.pyc in request(method, url, **kwargs)
#      76     kwargs['verify'] = config.get_config()['plotly_ssl_verification']
#      77     try:
# ---> 78         response = requests.request(method, url, **kwargs)
#      79     except RequestException as e:
#      80         # The message can be an exception. E.g., MaxRetryError.
#
# /Applications/anaconda/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /Applications/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     516         :param \*\*kwargs: Optional arguments that ``request`` takes.
#     517         :rtype: requests.Response
# --> 518         """
#     519
#     520         kwargs.setdefault('allow_redirects', True)
#
# /Applications/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     637         gen = self.resolve_redirects(r, request, **kwargs)
#     638
# --> 639         # Resolve redirects if allowed.
#     640         history = [resp for resp in gen] if allow_redirects else []
#     641
#
# /Applications/anaconda/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     403         """
#     404
# --> 405         conn = self.get_connection(request.url, proxies)
#     406
#     407         self.cert_verify(conn, request.url, verify, cert)
#
# /Applications/anaconda/lib/python2.7/site-packages/requests/adapters.pyc in cert_verify(self, conn, url, verify, cert)
#     223
#     224             if not cert_loc or not os.path.exists(cert_loc):
# --> 225                 raise IOError("Could not find a suitable TLS CA certificate bundle, "
#     226                               "invalid path: {0}".format(cert_loc))
#     227
#
# IOError: Could not find a suitable TLS CA certificate bundle, invalid path: /Applications/anaconda/lib/python2.7/site-packages/requests/cacert.pem

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

print __version__ # requires version >= 1.9.0
# Out:
# 2.0.15

# %%
import cufflinks as cf
iplot(cf.datagen.lines().iplot(asFigure=True,
                               kind='scatter',xTitle='Dates',yTitle='Returns',title='Returns'))

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
labels=test['Amount_in_USD']
comm=[1 if values == 1 else 0 for values in test.Commodity_L2]
test['Commodity_L2']=comm
train1=test.drop(['Quarter','Amount_in_USD'],axis=1)

# %%
from sklearn.cross_validation import train_test_split
x_train, x_test, y_train, y_test = train_test_split(train1,labels, test_size = 0.10,random_state=2)

# %%
reg.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-53abde45ffcd> in <module>()
# ----> 1 reg.fit(x_train,y_train)
#
# /Applications/anaconda/lib/python2.7/site-packages/sklearn/linear_model/base.pyc in fit(self, X, y, sample_weight)
#     510         n_jobs_ = self.n_jobs
#     511         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 512                          y_numeric=True, multi_output=True)
#     513
#     514         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# /Applications/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     519     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     520                     ensure_2d, allow_nd, ensure_min_samples,
# --> 521                     ensure_min_features, warn_on_dtype, estimator)
#     522     if multi_output:
#     523         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /Applications/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     400         # make sure we actually converted to numeric:
#     401         if dtype_numeric and array.dtype.kind == "O":
# --> 402             array = array.astype(np.float64)
#     403         if not allow_nd and array.ndim >= 3:
#     404             raise ValueError("Found array with dim %d. %s expected <= 2."
#
# ValueError: could not convert string to float: PR_Department
# 1                                056-POLICE DEPARTMENT
# 2                                056-POLICE DEPARTMENT
# 3                     841-DEPARTMENT OF TRANSPORTATION
# 4
